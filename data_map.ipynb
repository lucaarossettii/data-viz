# %%
# !pip install plotly.express
# !pip install plotly
# !pip install pandas
# !pip install nbformat
# Out:
# Requirement already satisfied: plotly.express in /Users/lucarossetti/anaconda3/envs/data/lib/python3.11/site-packages (0.4.1)
# Requirement already satisfied: pandas>=0.20.0 in /Users/lucarossetti/anaconda3/envs/data/lib/python3.11/site-packages (from plotly.express) (2.1.1)
# Requirement already satisfied: plotly>=4.1.0 in /Users/lucarossetti/anaconda3/envs/data/lib/python3.11/site-packages (from plotly.express) (5.18.0)
# Requirement already satisfied: statsmodels>=0.9.0 in /Users/lucarossetti/anaconda3/envs/data/lib/python3.11/site-packages (from plotly.express) (0.14.1)
# Requirement already satisfied: scipy>=0.18 in /Users/lucarossetti/anaconda3/envs/data/lib/python3.11/site-packages (from plotly.express) (1.11.4)
# Requirement already satisfied: patsy>=0.5 in /Users/lucarossetti/anaconda3/envs/data/lib/python3.11/site-packages (from plotly.express) (0.5.6)
# Requirement already satisfied: numpy>=1.11 in /Users/lucarossetti/anaconda3/envs/data/lib/python3.11/site-packages (from plotly.express) (1.26.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/lucarossetti/anaconda3/envs/data/lib/python3.11/site-packages (from pandas>=0.20.0->plotly.express) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/lucarossetti/anaconda3/envs/data/lib/python3.11/site-packages (from pandas>=0.20.0->plotly.express) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/lucarossetti/anaconda3/envs/data/lib/python3.11/site-packages (from pandas>=0.20.0->plotly.express) (2023.3)
# Requirement already satisfied: six in /Users/lucarossetti/anaconda3/envs/data/lib/python3.11/site-packages (from patsy>=0.5->plotly.express) (1.16.0)
# Requirement already satisfied: tenacity>=6.2.0 in /Users/lucarossetti/anaconda3/envs/data/lib/python3.11/site-packages (from plotly>=4.1.0->plotly.express) (8.2.3)
# Requirement already satisfied: packaging in /Users/lucarossetti/anaconda3/envs/data/lib/python3.11/site-packages (from plotly>=4.1.0->plotly.express) (23.2)
# Requirement already satisfied: plotly in /Users/lucarossetti/anaconda3/envs/data/lib/python3.11/site-packages (5.18.0)
# Requirement already satisfied: tenacity>=6.2.0 in /Users/lucarossetti/anaconda3/envs/data/lib/python3.11/site-packages (from plotly) (8.2.3)
# Requirement already satisfied: packaging in /Users/lucarossetti/anaconda3/envs/data/lib/python3.11/site-packages (from plotly) (23.2)
# Requirement already satisfied: pandas in /Users/lucarossetti/anaconda3/envs/data/lib/python3.11/site-packages (2.1.1)
# Requirement already satisfied: numpy>=1.23.2 in /Users/lucarossetti/anaconda3/envs/data/lib/python3.11/site-packages (from pandas) (1.26.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/lucarossetti/anaconda3/envs/data/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/lucarossetti/anaconda3/envs/data/lib/python3.11/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/lucarossetti/anaconda3/envs/data/lib/python3.11/site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in /Users/lucarossetti/anaconda3/envs/data/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: nbformat in /Users/lucarossetti/anaconda3/envs/data/lib/python3.11/site-packages (5.9.2)
# Requirement already satisfied: fastjsonschema in /Users/lucarossetti/anaconda3/envs/data/lib/python3.11/site-packages (from nbformat) (2.19.1)
# Requirement already satisfied: jsonschema>=2.6 in /Users/lucarossetti/anaconda3/envs/data/lib/python3.11/site-packages (from nbformat) (4.20.0)
# Requirement already satisfied: jupyter-core in /Users/lucarossetti/anaconda3/envs/data/lib/python3.11/site-packages (from nbformat) (5.3.0)
# Requirement already satisfied: traitlets>=5.1 in /Users/lucarossetti/anaconda3/envs/data/lib/python3.11/site-packages (from nbformat) (5.12.0)
# Requirement already satisfied: attrs>=22.2.0 in /Users/lucarossetti/anaconda3/envs/data/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/lucarossetti/anaconda3/envs/data/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/lucarossetti/anaconda3/envs/data/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat) (0.32.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/lucarossetti/anaconda3/envs/data/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat) (0.16.2)
# Requirement already satisfied: platformdirs>=2.5 in /Users/lucarossetti/anaconda3/envs/data/lib/python3.11/site-packages (from jupyter-core->nbformat) (3.11.0)

# %%
import pandas as pd
import plotly.express as px

# Load your data
data = pd.read_csv('FAOSTAT_data_en_1-7-2024.csv')

# Create an interactive map using Plotly with a default color scale
fig = px.choropleth(
    data, 
    locations="Area", 
    locationmode="country names",
    color="Value", 
    hover_name="Area", 
    animation_frame="Year",
    color_continuous_scale=px.colors.sequential.Plasma,  
    projection="natural earth",
    title="Average Temperature Change by Country compared to 1960 ",
    range_color=[-1, 2.5]  
)

# Update layout to add a slider for years and improve map aesthetics
fig.update_layout(
    geo=dict(showframe=False, showcoastlines=False),
    margin={"r":0,"t":30,"l":0,"b":0},  
    title_x=0.5,  
    coloraxis_colorbar=dict(title='Change in °C')  
)

fig.show()
